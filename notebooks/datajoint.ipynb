# %%
# %load_ext autoreload
# %autoreload 2
import datajoint as dj
from nbd.annotation_schema import CroppedImageLabel,CroppedImage,CroppedDatasetImage
import numpy as np
import matplotlib.pyplot as plt
# Out:
# [2025-04-23 04:06:50,702][INFO]: DataJoint 0.14.4 connected to root@localhost:3306

# %%
(CroppedImageLabel & {'fname':np.unique(CroppedImageLabel.fetch('fname'))[3]}).showall()

# %%
(CroppedDatasetImage & CroppedDatasetImage.fetch('KEY')[1000]).show()

# %%
(CroppedImage & CroppedImage.fetch('KEY')[1]).show()
# Out:
# <Axes: >

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# ...

# %%
fname,img = np.random.choice(Image.fetch())

# %%
img
# Out:
# array([[[ 63,  52,  40],
#         [ 63,  52,  42],
#         [ 63,  52,  40],
#         ...,
#         [ 21,  22,  16],
#         [ 20,  21,  16],
#         [ 19,  20,  15]],
#
#        [[ 64,  54,  42],
#         [ 64,  53,  43],
#         [ 64,  53,  42],
#         ...,
#         [ 21,  22,  16],
#         [ 21,  22,  17],
#         [ 21,  21,  17]],
#
#        [[ 63,  55,  43],
#         [ 63,  55,  44],
#         [ 63,  55,  44],
#         ...,
#         [ 20,  20,  17],
#         [ 20,  20,  18],
#         [ 19,  19,  17]],
#
#        ...,
#
#        [[186,  73,  77],
#         [186,  73,  76],
#         [186,  74,  73],
#         ...,
#         [162,  59,  62],
#         [167,  63,  66],
#         [167,  64,  66]],
#
#        [[187,  72,  77],
#         [187,  72,  76],
#         [187,  73,  73],
#         ...,
#         [161,  58,  61],
#         [166,  62,  66],
#         [167,  64,  66]],
#
#        [[187,  72,  78],
#         [188,  73,  78],
#         [188,  73,  76],
# ...
